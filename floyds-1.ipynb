# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nodes_df= pd.read_csv('Chennai_neighbourhood_cleaned.csv')

# %%
nodes_df
# Out:
#                Area                Location  Latitude  Longitude
# 0        Adambakkam  South and East Chennai  12.98800   80.20470
# 1             Adyar  South and East Chennai  13.00120   80.25650
# 2           Alandur  South and East Chennai  12.99750   80.20060
# 3         Alapakkam            West Chennai  13.04900   80.16730
# 4   Alwarthirunagar            West Chennai  13.04260   80.18400
# 5          Ambattur            West Chennai  13.11430   80.15480
# 6       Aminjikarai            West Chennai  13.06980   80.22450
# 7        Anna Nagar            West Chennai  13.08500   80.21010
# 8           Annanur            West Chennai  13.11840   80.12460
# 9        Arumbakkam            West Chennai  13.07240   80.21020
# 10      Ashok Nagar            West Chennai  13.03730   80.21230
# 11            Avadi            West Chennai  13.10670   80.09700
# 12       Ayappakkam            West Chennai  13.09250   80.13720
# ...

# %%
# TO OBTAIN BASIC DATA OF DATAFRAME
nodes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Area       50 non-null     object
#  1   Location   50 non-null     object
#  2   Latitude   50 non-null     float64
#  3   Longitude  50 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 1.7+ KB

# %%
import numpy as np
import pandas as pd

def generate_adjacency_matrix(locations):
    num_locations = len(locations)
    np.random.seed(42)
    adj_matrix = np.random.randint(1, 100, size=(num_locations, num_locations))
    np.fill_diagonal(adj_matrix, 0)  # Distance to itself is 0
    return adj_matrix

def floyd_warshall(matrix):
    """Applies Floyd-Warshall algorithm to find shortest paths between all pairs."""
    n = len(matrix)
    dist = matrix.copy()
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dist[i, j] = min(dist[i, j], dist[i, k] + dist[k, j])
    
    return dist

# Load dataset
file_path = "Chennai_neighbourhood_cleaned.csv"
df = pd.read_csv(file_path)
locations = df["Area"].tolist()

# Generate adjacency matrix
adj_matrix = generate_adjacency_matrix(locations)

# Compute shortest paths
shortest_paths = floyd_warshall(adj_matrix)

# Convert to DataFrame for better visualization
adj_matrix_df = pd.DataFrame(adj_matrix, index=locations, columns=locations)
shortest_paths_df = pd.DataFrame(shortest_paths, index=locations, columns=locations)

# Display the matrices
print("Adjacency Matrix:")
print(adj_matrix_df)
print("\nShortest Paths Matrix:")
print(shortest_paths_df)
# Out:
# Adjacency Matrix:
#                  Adambakkam  Adyar  Alandur  Alapakkam  Alwarthirunagar  \
# Adambakkam                0     93       15         72               61
# Adyar                     4      0       60         14                9
# Alandur                  60     41        0         15               45
# Alapakkam                79     15       90          0               77
# Alwarthirunagar          37     97       51         44                0
# Ambattur                 97     73       59         70               80
# Aminjikarai              20     24       54         33               24
# Anna Nagar               97     28       64         97               69
# Annanur                  90     17       33          9               43
# Arumbakkam               60     97        8         53               60
# Ashok Nagar              51     86       57         29               78
# Avadi                    12     67       65         33               40
# ...

# %%
print(shortest_paths_df)
# Out:
#                  Adambakkam  Adyar  Alandur  Alapakkam  Alwarthirunagar  \
# Adambakkam                0     12        8          8                6
# Adyar                     4      0        6          8                6
# Alandur                   6      9        0          8                6
# Alapakkam                10     12        8          0                8
# Alwarthirunagar           8      8        3          9                0
# Ambattur                  8      8        5          4                2
# Aminjikarai              15     19       14         15               13
# Anna Nagar                7     12        9         10                8
# Annanur                  13     13       12          9                9
# Arumbakkam                9      8        5          4                2
# Ashok Nagar              10      8       11         13                8
# Avadi                     4     15       12         11                9
# ...

# %%
import numpy as np
import pandas as pd

def generate_adjacency_matrix(locations):
    num_locations = len(locations)
    np.random.seed(42)
    adj_matrix = np.random.randint(1, 100, size=(num_locations, num_locations))
    np.fill_diagonal(adj_matrix, 0)  # Distance to itself is 0
    return adj_matrix

def floyd_warshall(matrix):
    """Applies Floyd-Warshall algorithm to find shortest paths between all pairs."""
    n = len(matrix)
    dist = matrix.copy()
    
    for k in range(n):
        for i in range(n):
            for j in range(n):
                dist[i, j] = min(dist[i, j], dist[i, k] + dist[k, j])
    
    return dist

# Load dataset
file_path = "Chennai_neighbourhood_cleaned.csv"
df = pd.read_csv(file_path)
locations = df["Area"].tolist()

# Generate adjacency matrix
adj_matrix = generate_adjacency_matrix(locations)

# Compute shortest paths
shortest_paths = floyd_warshall(adj_matrix)

# Convert to DataFrame for better visualization
adj_matrix_df = pd.DataFrame(adj_matrix, index=locations, columns=locations)
shortest_paths_df = pd.DataFrame(shortest_paths, index=locations, columns=locations)

# Convert shortest paths DataFrame to array
shortest_paths_array = shortest_paths_df.values

# Initialize lists for features (X) and labels (y)
X = []
y = []

# Process the matrix to extract features and labels
for i in range(shortest_paths_array.shape[0]):
    for j in range(shortest_paths_array.shape[1]):
        if i != j and not np.isinf(shortest_paths_array[i][j]):  # Exclude diagonal and inf values
            X.append(shortest_paths_array[i][j])
            y.append(1 if shortest_paths_array[i][j] < 10 else 0)  # Label based on threshold

# Convert lists to arrays and reshape X for ML model
X = np.array(X).reshape(-1, 1)
y = np.array(y)

# Display the matrices

print("\nShortest Paths Matrix:")
print(shortest_paths_df)

# Display sample of features and labels
print("\nSample Features and Labels:")
print(list(zip(X.flatten()[:10], y[:10])))
# Out:
# Shortest Paths Matrix:
#                  Adambakkam  Adyar  Alandur  Alapakkam  Alwarthirunagar  \
# Adambakkam                0     12        8          8                6
# Adyar                     4      0        6          8                6
# Alandur                   6      9        0          8                6
# Alapakkam                10     12        8          0                8
# Alwarthirunagar           8      8        3          9                0
# Ambattur                  8      8        5          4                2
# Aminjikarai              15     19       14         15               13
# Anna Nagar                7     12        9         10                8
# Annanur                  13     13       12          9                9
# Arumbakkam                9      8        5          4                2
# Ashok Nagar              10      8       11         13                8
# Avadi                     4     15       12         11                9
# ...

# %%
# Split into training and testing datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train a RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)

def print_solution(matrix, locations):
    """Prints the shortest paths matrix with location names."""
    print("\nShortest Paths Matrix:")
    df = pd.DataFrame(matrix, index=locations, columns=locations)
    print(df)

# Call the function correctly
print_solution(shortest_paths_array, locations)
# Out:
# Model Accuracy: 1.0
#
# Shortest Paths Matrix:
#                  Adambakkam  Adyar  Alandur  Alapakkam  Alwarthirunagar  \
# Adambakkam                0     12        8          8                6
# Adyar                     4      0        6          8                6
# Alandur                   6      9        0          8                6
# Alapakkam                10     12        8          0                8
# Alwarthirunagar           8      8        3          9                0
# Ambattur                  8      8        5          4                2
# Aminjikarai              15     19       14         15               13
# Anna Nagar                7     12        9         10                8
# Annanur                  13     13       12          9                9
# Arumbakkam                9      8        5          4                2
# Ashok Nagar              10      8       11         13                8
# ...

# %%
pip install folium
# Out:
# ...
#   Using cached folium-0.19.4-py2.py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# ...
# Using cached folium-0.19.4-py2.py3-none-any.whl (110 kB)
# Using cached branca-0.8.1-py3-none-any.whl (26 kB)
# Using cached xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium

def predict_shortest_path(start_location, end_location):
    """Predicts and displays the shortest path for given locations."""
    if start_location not in locations or end_location not in locations:
        print("Error: One or both locations not found in dataset.")
        return

    # Get indices for locations
    start_idx = locations.index(start_location)
    end_idx = locations.index(end_location)

    # Get the shortest distance from the precomputed matrix
    shortest_distance = shortest_paths_array[start_idx][end_idx]

    # Prepare input for the model
    input_feature = np.array([[shortest_distance]])

    # Predict the classification (short or long path)
    prediction = model.predict(input_feature)[0]
    prediction_label = "Short Path" if prediction == 1 else "Long Path"

    print(f"Predicted path classification: {prediction_label}")
    print(f"Shortest distance between {start_location} and {end_location}: {shortest_distance} units")

    # Map Visualization (Optional)
    map_center = [df.loc[df["Area"] == start_location, "Latitude"].values[0], 
                  df.loc[df["Area"] == start_location, "Longitude"].values[0]]
    
    map_obj = folium.Map(location=map_center, zoom_start=12)

    # Add markers for start and end locations
    folium.Marker(
        location=[df.loc[df["Area"] == start_location, "Latitude"].values[0],
                  df.loc[df["Area"] == start_location, "Longitude"].values[0]],
        popup=start_location,
        icon=folium.Icon(color="green")
    ).add_to(map_obj)

    folium.Marker(
        location=[df.loc[df["Area"] == end_location, "Latitude"].values[0],
                  df.loc[df["Area"] == end_location, "Longitude"].values[0]],
        popup=end_location,
        icon=folium.Icon(color="red")
    ).add_to(map_obj)

    return map_obj

# Example usage:
start = "Alandur"
end = "Adyar"
map_output = predict_shortest_path(start, end)
map_output  # Display the interactive map (in Jupyter Notebook)
# Out:
# Predicted path classification: Short Path
# Shortest distance between Alandur and Adyar: 9 units
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium

def predict_shortest_path(start_location, end_location):
    """Predicts and displays the shortest path for given locations on a map with a connecting line."""
    if start_location not in locations or end_location not in locations:
        print("Error: One or both locations not found in dataset.")
        return

    # Get indices for locations
    start_idx = locations.index(start_location)
    end_idx = locations.index(end_location)

    # Get the shortest distance from the precomputed matrix
    shortest_distance = shortest_paths_array[start_idx][end_idx]

    # Prepare input for the model
    input_feature = np.array([[shortest_distance]])

    # Predict the classification (short or long path)
    prediction = model.predict(input_feature)[0]
    prediction_label = "Short Path" if prediction == 1 else "Long Path"

    print(f"Predicted path classification: {prediction_label}")
    print(f"Shortest distance between {start_location} and {end_location}: {shortest_distance} units")

    # Get coordinates
    start_lat = df.loc[df["Area"] == start_location, "Latitude"].values[0]
    start_lon = df.loc[df["Area"] == start_location, "Longitude"].values[0]
    end_lat = df.loc[df["Area"] == end_location, "Latitude"].values[0]
    end_lon = df.loc[df["Area"] == end_location, "Longitude"].values[0]

    # Create map centered at the start location
    map_obj = folium.Map(location=[start_lat, start_lon], zoom_start=12)

    # Add markers for start and end locations
    folium.Marker(
        location=[start_lat, start_lon],
        popup=start_location,
        icon=folium.Icon(color="green", icon="play")
    ).add_to(map_obj)

    folium.Marker(
        location=[end_lat, end_lon],
        popup=end_location,
        icon=folium.Icon(color="red", icon="flag")
    ).add_to(map_obj)

    # Draw a line between the locations
    folium.PolyLine(
        locations=[[start_lat, start_lon], [end_lat, end_lon]],
        color="blue",
        weight=5,
        opacity=0.7
    ).add_to(map_obj)

    return map_obj

# Example usage:
start = "Egmore"
end = "Adyar"
map_output = predict_shortest_path(start, end)
map_output  # Displays the interactive map (works in Jupyter Notebook)
# Out:
# Predicted path classification: Short Path
# Shortest distance between Egmore and Adyar: 9 units
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
